# %% [markdown]
# <h1 style="text-align: center;">◽ Análises gráficas e experimentações 📌 </h1>

# %%
#bibliotecas

import matplotlib.pyplot as plt
import numpy as np

# %%
#grafico - assinatura 

dados = np.loadtxt("coordenadas_assinatura.tsv")
x = dados[:, 0]
y = dados[:, 1]

plt.title("Assinatura em termos das coordenadas")
plt.plot(x, y, c = 'k')
plt.show()

# %%
#grafico - pressao 

dados = np.loadtxt("coordenadas_assinatura.tsv")
# frequencia = 1/T -> ciclos/segundos -> 100Hz
y = dados[:, 2]
x = np.arange(len(dados)) / 100  #cria um array com intervalos igualmente espaçados

plt.xlabel("Tempo (s)")
plt.ylabel("Pressão (Pa)")
plt.plot(x, y)
plt.show()
